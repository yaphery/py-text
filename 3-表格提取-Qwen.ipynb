# %%
import json
import os
import dashscope
from dashscope.api_entities.dashscope_response import Role
# 从环境变量中，获取 DASHSCOPE_API_KEY
api_key = os.environ.get('DASHSCOPE_API_KEY')
dashscope.api_key = api_key

# 封装模型响应函数
def get_response(messages):
    response = dashscope.MultiModalConversation.call(
        model='qwen-vl-plus',
        messages=messages
    )
    return response

content = [
    {'image': 'https://aiwucai.oss-cn-huhehaote.aliyuncs.com/pdf_table.jpg'}, # Either a local path or an url
    {'text': '这是一个表格图片，帮我提取里面的内容，输出JSON格式'}
]

messages=[{"role": "user", "content": content}]
# 得到响应
response = get_response(messages)
response
# Out:
# MultiModalConversationResponse(status_code=<HTTPStatus.OK: 200>, request_id='6d19815f-a782-4786-b9b2-51ef71702dbc', code='', message='', output=MultiModalConversationOutput(choices=[Choice(finish_reason='stop', message=Message({'role': 'assistant', 'content': [{'text': '根据提供的表格图片，以下是提取的内容并以JSON格式输出：\n\n```json\n{\n  "客户信息": {\n    "联系方式": "",\n    "回复时间": "",\n    "生产日期": {\n      "年": "",\n      "月": ""\n    },\n    "数量": 1,\n    "严重程度": {\n      "一般": "",\n      "紧急程度": {\n        "一般": "",\n        "紧急": ""\n      }\n    },\n    "产品型号": "",\n    "客户诉求": {\n      "数量": 1,\n      "客户诉求点": [\n        "退货",\n        "换修"\n      ]\n    },\n    "图例说明": ""\n  },\n  "分析人": "2018年__月__日",\n  "整改措施": {\n    "零时对策": {\n      "内容": "更换压头，更换阀盘",\n      "措施": [\n        "□库存产品再检验",\n        "□退回二级纠正",\n        "□其它"\n      ]\n    },\n    "1.防止发生对策": "",\n    "建言人": "日期：2018年__月__日",\n    "要求完成时间": "2018年__月__日",\n    "进程追踪": "□按时完成 □延期完成 □未完成",\n    "纠正归属": [\n      "□设计部",\n      "□品质部",\n      "□装配车间",\n      "□压铸车间",\n      "□车床车间",\n      "□仓库",\n      "□运输",\n      "□其它"\n    ]\n  },\n  "备注说明": ""\n}\n```\n\n### 解释：\n- **客户信息**：包括联系方式、回复时间、生产日期、数量、严重程度（分为一般和紧急）、产品型号、客户诉求及其详细点。\n- **分析人**：记录了分析人的姓名和日期。\n- **整改措施**：分为零时对策和防止发生对策，零时对策中列出了具体的措施，如更换压头、更换阀盘等，并提供了多种处理方式的选项。防止发生对策为空白，需要填写具体措施。\n- **建言人**：记录了建言人的姓名和日期。\n- **要求完成时间**：记录了要求完成的时间。\n- **进程追踪**：提供了按时完成、延期完成和未完成的选项。\n- **纠正归属**：列出了可能涉及的部门或车间，如设计部、品质部、装配车间等。\n- **备注说明**：用于记录额外的信息或说明。\n\n希望这个JSON格式的输出能满足您的需求！如果有任何进一步的修改或补充，请随时告知。'}]}))]), usage=MultiModalConversationUsage(input_tokens=790, output_tokens=549))

# %%
print(response.output.choices[0].message.content[0]['text'])
# Out:
# 根据提供的表格图片，以下是提取的内容并以JSON格式输出：
#
# ```json
# {
#   "客户信息": {
#     "联系方式": "",
#     "回复时间": "",
#     "生产日期": {
#       "年": "",
#       "月": ""
#     },
#     "数量": 1,
#     "严重程度": {
#       "一般": "",
#       "紧急程度": {
#         "一般": "",
#         "紧急": ""
#       }
#     },
#     "产品型号": "",
#     "客户诉求": {
#       "数量": 1,
#       "客户诉求点": [
#         "退货",
#         "换修"
#       ]
#     },
#     "图例说明": ""
#   },
#   "分析人": "2018年__月__日",
#   "整改措施": {
#     "零时对策": {
#       "内容": "更换压头，更换阀盘",
#       "措施": [
#         "□库存产品再检验",
#         "□退回二级纠正",
#         "□其它"
#       ]
#     },
#     "1.防止发生对策": "",
#     "建言人": "日期：2018年__月__日",
#     "要求完成时间": "2018年__月__日",
#     "进程追踪": "□按时完成 □延期完成 □未完成",
#     "纠正归属": [
#       "□设计部",
#       "□品质部",
#       "□装配车间",
#       "□压铸车间",
#       "□车床车间",
#       "□仓库",
#       "□运输",
#       "□其它"
#     ]
#   },
#   "备注说明": ""
# }
# ```
#
# ### 解释：
# - **客户信息**：包括联系方式、回复时间、生产日期、数量、严重程度（分为一般和紧急）、产品型号、客户诉求及其详细点。
# - **分析人**：记录了分析人的姓名和日期。
# - **整改措施**：分为零时对策和防止发生对策，零时对策中列出了具体的措施，如更换压头、更换阀盘等，并提供了多种处理方式的选项。防止发生对策为空白，需要填写具体措施。
# - **建言人**：记录了建言人的姓名和日期。
# - **要求完成时间**：记录了要求完成的时间。
# - **进程追踪**：提供了按时完成、延期完成和未完成的选项。
# - **纠正归属**：列出了可能涉及的部门或车间，如设计部、品质部、装配车间等。
# - **备注说明**：用于记录额外的信息或说明。
#
# 希望这个JSON格式的输出能满足您的需求！如果有任何进一步的修改或补充，请随时告知。
